# %%
import sys
import os
import glob
import h5py
import numpy as np
import matplotlib.pyplot as plt
from numpy.fft import rfft, irfft
from matplotlib.animation import FuncAnimation

current_dir = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(current_dir, '..')))
h5_files = glob.glob(os.path.join("..\\output", "*.h5"))

eta_hat, phi_hat, Hs, Tp, modes, time, length, x = None, None, None, None, None, None, None, None

for i, file in enumerate(h5_files):
    with h5py.File(file, "r") as data:
        eta_hat = data["eta_hat"][:]
        phi_hat = data["phi_hat"][:]
        Hs = data["Hs"][:]
        Tp = data["Tp"][:]
        time = data["time"][:]

        modes = data.attrs["modes"]
        length = data.attrs["length"]
        Ta = data.attrs["Ta"]
        x = np.linspace(0, length, 2*modes)

    break

index = np.argmin(np.abs(time - 2*Ta))

eta_hat = eta_hat[:, index:, :]
phi_hat = phi_hat[:, index:, :]
time = time[index:] - time[index]

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping
from numpy.fft import irfft, rfft

inputs = keras.Input(shape=(1026,))
x_ = layers.Dense(512, activation='relu')(inputs)
x_ = layers.Dense(512, activation='relu')(x_)
outputs = layers.Dense(1026)(x_)

# inputs = keras.Input(shape=(1026, 1))  # Add channel dimension for CNN
# x_ = layers.Conv1D(32, kernel_size=5, padding='same', activation='relu')(inputs)
# x_ = layers.Conv1D(32, kernel_size=5, padding='same', activation='relu')(x_)
# x_ = layers.Conv1D(32, kernel_size=5, padding='same', activation='relu')(x_)
# x_ = layers.Conv1D(1, kernel_size=5, padding='same')(x_)  # Output one channel
# outputs = layers.Flatten()(x_)  # Flatten to (1026,) output

model = keras.Model(inputs=inputs, outputs=outputs)

model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss='mse',
    metrics=['mae']
)

# model.summary()
prediction_time = 60
train_percentage = 0.9
batch_size = 32

# X = eta_hat[0, :-prediction_time, :]
# y = eta_hat[0, prediction_time:, :]
# X = irfft(X)
# y = irfft(y)

X = eta_hat[0, :-prediction_time, :]
y = eta_hat[0, prediction_time:, :]
X = np.concatenate((np.real(X), np.imag(X)), axis=1)
y = np.concatenate((np.real(y), np.imag(y)), axis=1)


X_train = X[:int(X.shape[0]*train_percentage), :]
X_test = X[int(X.shape[0]*train_percentage):, :]
y_train = y[:int(y.shape[0]*train_percentage), :]
y_test = y[int(y.shape[0]*train_percentage):, :]

std = np.std(X)
X_train = X_train / std
y_train = y_train / std

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True
)

history = model.fit(
    X_train, y_train,
    validation_split=0.1,
    batch_size=batch_size,
    epochs=1000,
    callbacks=[early_stopping],
    shuffle=True
)
# Out:
# Epoch 1/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.0165 - mae: 0.4261 - val_loss: 0.7899 - val_mae: 0.4469
# Epoch 2/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.5791 - mae: 0.4148 - val_loss: 0.4986 - val_mae: 0.4159
# Epoch 3/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3151 - mae: 0.3366 - val_loss: 0.3684 - val_mae: 0.3736
# Epoch 4/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2078 - mae: 0.2852 - val_loss: 0.3085 - val_mae: 0.3467
# Epoch 5/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1564 - mae: 0.2467 - val_loss: 0.2708 - val_mae: 0.3381
# Epoch 6/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1274 - mae: 0.2290 - val_loss: 0.2481 - val_mae: 0.3215
# Epoch 7/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1027 - mae: 0.2073 - val_loss: 0.2196 - val_mae: 0.3006
# Epoch 8/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0817 - mae: 0.1851 - val_loss: 0.2048 - val_mae: 0.2890
# Epoch 9/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0679 - mae: 0.1713 - val_loss: 0.1916 - val_mae: 0.2783
# Epoch 10/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0551 - mae: 0.1558 - val_loss: 0.1859 - val_mae: 0.2743
# Epoch 11/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0488 - mae: 0.1479 - val_loss: 0.1804 - val_mae: 0.2665
# Epoch 12/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0434 - mae: 0.1390 - val_loss: 0.1786 - val_mae: 0.2654
# Epoch 13/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0389 - mae: 0.1327 - val_loss: 0.1729 - val_mae: 0.2586
# Epoch 14/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0339 - mae: 0.1240 - val_loss: 0.1730 - val_mae: 0.2558
# Epoch 15/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0303 - mae: 0.1165 - val_loss: 0.1700 - val_mae: 0.2518
# Epoch 16/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0282 - mae: 0.1128 - val_loss: 0.1704 - val_mae: 0.2537
# Epoch 17/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0269 - mae: 0.1105 - val_loss: 0.1685 - val_mae: 0.2514
# Epoch 18/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0230 - mae: 0.1037 - val_loss: 0.1678 - val_mae: 0.2474
# Epoch 19/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0224 - mae: 0.1036 - val_loss: 0.1688 - val_mae: 0.2482
# Epoch 20/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0212 - mae: 0.0984 - val_loss: 0.1665 - val_mae: 0.2436
# Epoch 21/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0191 - mae: 0.0944 - val_loss: 0.1664 - val_mae: 0.2406
# Epoch 22/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0194 - mae: 0.0947 - val_loss: 0.1636 - val_mae: 0.2389
# Epoch 23/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0160 - mae: 0.0873 - val_loss: 0.1621 - val_mae: 0.2351
# Epoch 24/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0150 - mae: 0.0831 - val_loss: 0.1627 - val_mae: 0.2358
# Epoch 25/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0153 - mae: 0.0832 - val_loss: 0.1614 - val_mae: 0.2334
# Epoch 26/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0140 - mae: 0.0814 - val_loss: 0.1618 - val_mae: 0.2318
# Epoch 27/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0137 - mae: 0.0797 - val_loss: 0.1627 - val_mae: 0.2334
# Epoch 28/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0144 - mae: 0.0794 - val_loss: 0.1618 - val_mae: 0.2306
# Epoch 29/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0132 - mae: 0.0776 - val_loss: 0.1619 - val_mae: 0.2315
# Epoch 30/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0143 - mae: 0.0790 - val_loss: 0.1597 - val_mae: 0.2268
# Epoch 31/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0117 - mae: 0.0716 - val_loss: 0.1597 - val_mae: 0.2262
# Epoch 32/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0120 - mae: 0.0712 - val_loss: 0.1593 - val_mae: 0.2286
# Epoch 33/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0128 - mae: 0.0754 - val_loss: 0.1595 - val_mae: 0.2220
# Epoch 34/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0124 - mae: 0.0709 - val_loss: 0.1574 - val_mae: 0.2215
# Epoch 35/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0117 - mae: 0.0698 - val_loss: 0.1609 - val_mae: 0.2259
# Epoch 36/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0125 - mae: 0.0726 - val_loss: 0.1608 - val_mae: 0.2243
# Epoch 37/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0108 - mae: 0.0686 - val_loss: 0.1626 - val_mae: 0.2246
# Epoch 38/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0134 - mae: 0.0715 - val_loss: 0.1626 - val_mae: 0.2199
# Epoch 39/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0127 - mae: 0.0689 - val_loss: 0.1578 - val_mae: 0.2171
# Epoch 40/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0115 - mae: 0.0662 - val_loss: 0.1583 - val_mae: 0.2187
# Epoch 41/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0108 - mae: 0.0649 - val_loss: 0.1565 - val_mae: 0.2146
# Epoch 42/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0102 - mae: 0.0661 - val_loss: 0.1646 - val_mae: 0.2261
# Epoch 43/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0134 - mae: 0.0706 - val_loss: 0.1593 - val_mae: 0.2191
# Epoch 44/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0113 - mae: 0.0694 - val_loss: 0.1597 - val_mae: 0.2204
# Epoch 45/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0120 - mae: 0.0693 - val_loss: 0.1554 - val_mae: 0.2158
# Epoch 46/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0091 - mae: 0.0628 - val_loss: 0.1568 - val_mae: 0.2152
# Epoch 47/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0108 - mae: 0.0656 - val_loss: 0.1573 - val_mae: 0.2174
# Epoch 48/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0105 - mae: 0.0639 - val_loss: 0.1560 - val_mae: 0.2164
# Epoch 49/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0096 - mae: 0.0626 - val_loss: 0.1564 - val_mae: 0.2115
# Epoch 50/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0117 - mae: 0.0626 - val_loss: 0.1556 - val_mae: 0.2141
# Epoch 51/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0100 - mae: 0.0645 - val_loss: 0.1561 - val_mae: 0.2153
# Epoch 52/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0099 - mae: 0.0662 - val_loss: 0.1544 - val_mae: 0.2116
# Epoch 53/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0082 - mae: 0.0612 - val_loss: 0.1542 - val_mae: 0.2093
# Epoch 54/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0086 - mae: 0.0587 - val_loss: 0.1534 - val_mae: 0.2076
# Epoch 55/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0096 - mae: 0.0588 - val_loss: 0.1551 - val_mae: 0.2093
# Epoch 56/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0097 - mae: 0.0625 - val_loss: 0.1546 - val_mae: 0.2089
# Epoch 57/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0141 - mae: 0.0683 - val_loss: 0.1563 - val_mae: 0.2088
# Epoch 58/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0130 - mae: 0.0670 - val_loss: 0.1583 - val_mae: 0.2154
# Epoch 59/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0115 - mae: 0.0687 - val_loss: 0.1543 - val_mae: 0.2049
# Epoch 60/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0088 - mae: 0.0584 - val_loss: 0.1571 - val_mae: 0.2114
# Epoch 61/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0118 - mae: 0.0665 - val_loss: 0.1528 - val_mae: 0.2045
# Epoch 62/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0097 - mae: 0.0601 - val_loss: 0.1547 - val_mae: 0.2066
# Epoch 63/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0114 - mae: 0.0605 - val_loss: 0.1545 - val_mae: 0.2079
# Epoch 64/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0108 - mae: 0.0653 - val_loss: 0.1595 - val_mae: 0.2096
# Epoch 65/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0109 - mae: 0.0613 - val_loss: 0.1567 - val_mae: 0.2086
# Epoch 66/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0113 - mae: 0.0631 - val_loss: 0.1559 - val_mae: 0.2056
# Epoch 67/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0099 - mae: 0.0602 - val_loss: 0.1546 - val_mae: 0.2052
# Epoch 68/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0088 - mae: 0.0579 - val_loss: 0.1533 - val_mae: 0.2039
# Epoch 69/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0082 - mae: 0.0565 - val_loss: 0.1538 - val_mae: 0.2009
# Epoch 70/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0083 - mae: 0.0549 - val_loss: 0.1509 - val_mae: 0.2015
# Epoch 71/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0075 - mae: 0.0545 - val_loss: 0.1521 - val_mae: 0.2003
# Epoch 72/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0070 - mae: 0.0530 - val_loss: 0.1544 - val_mae: 0.2035
# Epoch 73/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0089 - mae: 0.0563 - val_loss: 0.1546 - val_mae: 0.1992
# Epoch 74/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0090 - mae: 0.0557 - val_loss: 0.1541 - val_mae: 0.2017
# Epoch 75/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0086 - mae: 0.0566 - val_loss: 0.1525 - val_mae: 0.1995
# Epoch 76/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0099 - mae: 0.0565 - val_loss: 0.1552 - val_mae: 0.2037
# Epoch 77/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0110 - mae: 0.0608 - val_loss: 0.1559 - val_mae: 0.2067
# Epoch 78/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0106 - mae: 0.0622 - val_loss: 0.1541 - val_mae: 0.2016
# Epoch 79/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0105 - mae: 0.0585 - val_loss: 0.1592 - val_mae: 0.2086
# Epoch 80/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0113 - mae: 0.0642 - val_loss: 0.1555 - val_mae: 0.2073
# Epoch 81/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0099 - mae: 0.0603 - val_loss: 0.1523 - val_mae: 0.1982
# Epoch 82/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0079 - mae: 0.0546 - val_loss: 0.1502 - val_mae: 0.1958
# Epoch 83/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0065 - mae: 0.0494 - val_loss: 0.1533 - val_mae: 0.1965
# Epoch 84/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0084 - mae: 0.0532 - val_loss: 0.1490 - val_mae: 0.1920
# Epoch 85/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0082 - mae: 0.0530 - val_loss: 0.1522 - val_mae: 0.1977
# Epoch 86/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0087 - mae: 0.0556 - val_loss: 0.1526 - val_mae: 0.1956
# Epoch 87/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0116 - mae: 0.0585 - val_loss: 0.1523 - val_mae: 0.2002
# Epoch 88/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0105 - mae: 0.0628 - val_loss: 0.1544 - val_mae: 0.1994
# Epoch 89/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0105 - mae: 0.0608 - val_loss: 0.1516 - val_mae: 0.1945
# Epoch 90/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0081 - mae: 0.0554 - val_loss: 0.1504 - val_mae: 0.1934
# Epoch 91/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0072 - mae: 0.0510 - val_loss: 0.1514 - val_mae: 0.1930
# Epoch 92/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0090 - mae: 0.0527 - val_loss: 0.1539 - val_mae: 0.1986
# Epoch 93/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0094 - mae: 0.0575 - val_loss: 0.1537 - val_mae: 0.1984
# Epoch 94/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0103 - mae: 0.0587 - val_loss: 0.1531 - val_mae: 0.1930
# Epoch 95/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0093 - mae: 0.0555 - val_loss: 0.1525 - val_mae: 0.1934
# Epoch 96/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0083 - mae: 0.0537 - val_loss: 0.1514 - val_mae: 0.1914
# Epoch 97/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0078 - mae: 0.0520 - val_loss: 0.1581 - val_mae: 0.1994
# Epoch 98/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0130 - mae: 0.0604 - val_loss: 0.1577 - val_mae: 0.2005
# Epoch 99/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0137 - mae: 0.0630 - val_loss: 0.1518 - val_mae: 0.1926
# Epoch 100/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0100 - mae: 0.0579 - val_loss: 0.1543 - val_mae: 0.1936
# Epoch 101/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0094 - mae: 0.0550 - val_loss: 0.1536 - val_mae: 0.1985
# Epoch 102/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0092 - mae: 0.0563 - val_loss: 0.1525 - val_mae: 0.1928
# Epoch 103/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0075 - mae: 0.0530 - val_loss: 0.1571 - val_mae: 0.1984
# Epoch 104/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0128 - mae: 0.0629 - val_loss: 0.1546 - val_mae: 0.1952

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.title('Training and Validation Loss')
plt.show()

# %%
index = 0
y_pred = model.predict(X_test / std) * std
error = np.mean(np.mean(np.abs(y_pred - y_test), axis=-1))/Hs[0]*100
print(f"Hs: {Hs[0]:.3f}m, MAE/Hs: {error:.3f}%")
plt.figure(figsize=(12, 8))
plt.plot(x, y_pred[index], "r--", label="Prediction")
plt.plot(x, y_test[index], "k-", label="Ground Truth")
plt.xlim(x[0], x[-1])
plt.legend()
plt.grid()
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Hs: 2.320m, MAE/Hs: 9.044%

# %%
from numpy.fft import irfft

y_pred = model.predict(X_test / std) * std

index = 0
y_pred_real = irfft(y_pred[:, :513] + 1.j * y_pred[:, 513:])
y_test_real = irfft(y_test[:, :513] + 1.j * y_test[:, 513:])
error = np.mean(np.mean(np.abs(y_pred_real - y_test_real), axis=1))/Hs[0]*100
print(f"Hs: {Hs[0]:.3f}m, MAE/Hs: {error:.3f}%")
plt.figure(figsize=(12, 8))
plt.plot(x, y_pred_real[0], "r--", label="Prediction")
plt.plot(x, y_test_real[0], "k-", label="Ground Truth")
plt.xlim(x[0], 1000)
plt.legend()
plt.grid()
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Hs: 2.320m, MAE/Hs: 7.487%
